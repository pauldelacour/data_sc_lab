# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
df_beha = pd.read_csv('../../data/Behavioral/AllData.csv')#, nrows=1000)

df_psd_cluster = pd.read_csv("../../data/EEG/RestingEEG_PSD_Cluster.csv") #, nrows=1000)
df_psd_channel = pd.read_csv("../../data/EEG/RestingEEG_PSD_Channel.csv") #, nrows=5)
df_spectro_cluster = pd.read_csv("../../data/EEG/RestingEEG_Spectro_Cluster.csv") #, nrows=1000)
df_spectro_channel = pd.read_csv("../../data/EEG/RestingEEG_Spectro_Channel.csv") #, nrows=5)

df_microstate = pd.read_csv("../../data/EEG/RestingEEG_Microstates.csv") #, nrows=5)
# Out:
# /home/tristan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (66,68,80,81,82,83,84,95,96,97,98,99,110,111,112,113,114,125,126,127,128,129,140,141,142,144,155,156,157,159,932,933,934,935,936,937,938,939,940,941,942,943,944,945,946,947,948,949,950,951,952,953,954,955,956,957,958,959,960,961,962,963,964,965,966,967,968,969,970,971,972,973,974,975,976,977,978,979,980,981,982,983,984,985,986,987,988,989,990,991,992,993,994,995,996,997,998,999,1000,1001,1002,1003,1004,1005,1006,1007,1008,1009,1010,1011,1012,1013,1014,1015,1016,1017,1018,1019,1020,1021,1022,1023,1024,1025,1026,1027,1028,1029,1030,1031,1032,1033,1034,1035,1036,1037,1038,1039,1040,1041,1042,1043,1044,1045,1046,1047,1048,1049,1050,1051,1052,1053,1054,1055,1056,1057,1058,1059,1060,1061,1062,1063,1064,1065,1066,1067,1068,1069,1070,1071,1072,1073,1074,1075,1076,1077,1078,1079,1080,1081,1082,1083,1084,1085,1086,1087,1088,1089,1090,1091,1092,1093,1094,1095,1096,1097,1098,1099,1100,1101,1102,1103,1104,1105,1106,1107,1108,1109,1110,1111,1112,1113,1114,1115,1116,1117,1118,1119,1120,1121,1122,1123,1124,1125,1126,1127,1128,1129,1130,1131,1132,1133,1134,1135,1136,1137,1138,1139,1140,1141,1142,1143,1144,1145,1146,1147,1148,1149,1150,1151,1152,1153,1154,1155,1156,1157,1158,1159,1160,1161,1162,1163,1164,1165,1166,1167,1168,1169,1170,1171,1172,1173,1174,1175,1176,1177,1178,1179,1180,1181,1182,1183,1184,1185,1186,1187,1188,1189,1190,1191,1192,1193,1194,1195,1196,1197,1198,1199,1200,1201,1202,1203,1204,1205,1206,1207,1208,1209,1210,1211,1212,1213,1214,1215,1216,1217,1218,1219,1220,1221,1222,1223,1224,1225,1226,1227,1228,1229,1230,1231,1232,1233,1234,1235,1236,1237,1238,1239,1240,1241,1242,1243,1244,1245,1246,1247,1248,1249,1250,1251,1252,1253,1254,1255,1256,1257,1258,1259,1260,1261,1262,1263,1264,1265,1266,1267,1268,1269,1270,1271,1272,1273,1274,1275,1276,1277,1278,1279,1280,1281,1282,1283,1284,1285,1286,1287,1288,1289,1290,1291,1292,1293,1294,1295,1296,1297,1298,1299,1300,1301,1302,1303,1304,1305,1306,1307,1308,1309,1310,1311,1312,1313,1314,1315,1316,1317,1318,1319,1320,1321,1322,1323,1324,1325,1326,1327,1328,1329,1330,1331,1332,1333,1334,1335,1336,1337,1338,1339,1340,1341,1342,1343,1344,1345,1346,1347,1348,1349,1350,1351,1352,1353,1354,1355,1356,1357,1358,1359,1360,1361,1362,1363,1364,1365,1366,1367,1368,1369,1370,1371,1372,1373,1374,1375,1376,1377,1378,1379,1380,1381,1384,1385,1387,1390,1391,1393,1396,1397,1399,1402,1403,1405,1408,1409,1411,1414,1415,1417,1420,1421,1423,1426,1427,1429,1432,1433,1435,1438,1439,1441,1444,1445,1447,1450,1451,1453,1456,1457,1459,1462,1463,1465,1468,1469,1471,1474,1475,1477,1480,1481,1483,1486,1487,1489,1492,1493,1495,1498,1499,1501,1504,1505,1507,1510,1511,1513,1516,1517,1519,1522,1523,1525,1528,1529,1531,1534,1535,1537,1540,1541,1543,1546,1547,1549,1552,1553,1555,1558,1559,1561,1564,1565,1567,1570,1571,1573,1576,1577,1579,1582,1583,1585,1588,1589,1591,1594,1595,1597,1600,1601,1603,1606,1607,1609,1612,1613,1615,1618,1619,1621,1624,1625,1627,1630,1631,1633,1636,1637,1639,1642,1643,1645,1648,1649,1651,1654,1655,1657,1660,1661,1663,1666,1667,1669,1672,1673,1675,1678,1679,1681,1684,1685,1687,1690,1691,1693,1696,1697,1699,1702,1703,1705,1708,1709,1711,1714,1715,1717,1720,1721,1723,1726,1727,1729,1732,1733,1735,1738,1739,1741,1744,1745,1747,1750,1751,1753,1756,1757,1759,1762,1763,1765,1768,1769,1771,1774,1775,1777,1780,1781,1783,1786,1787,1789,1792,1793,1795,1798,1799,1801,1804,1805,1807,1810,1811,1813,1816,1817,1819,1822,1823,1825,1828,1829,1831,1834,1835,1837,1840,1841,1843,1846,1847,1849,1852,1853,1855,1858,1859,1861,1882,1883,1884,1917,1918,1919,1952,1953,1954,1955,1987,1988,1989,1990,2022,2023,2024,2025,2026,2057,2058,2059,2060,2061,2092,2093,2094,2095,2096,2097,2127,2128,2129,2130,2131,2132,2162,2163,2164,2165,2166,2167,2168,2197,2198,2199,2200,2201,2202,2203,2232,2233,2234,2235,2236,2237,2238,2239,2267,2268,2269,2270,2271,2272,2273,2274,2302,2303,2304,2305,2306,2307,2308,2309,2337,2338,2339,2340,2341,2 ...
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# # Behavioral data

# %%
# Extract relevant info from the Behavioral data 
y_labels = df_beha[["Patient_ID", "Age", "DX_01_Cat"]]
y_labels_healthy = y_labels[y_labels["DX_01_Cat"].str.contains("No Diagnosis Given") == True]

y_labels = y_labels[["Patient_ID", "Age"]]
y_labels_healthy = y_labels_healthy[["Patient_ID", "Age"]]
y_labels_healthy
# Out:
#         Patient_ID        Age
# 9     NDARCF462HNM  14.216632
# 11    NDARFC233RND   9.153661
# 22    NDARDT800YVF  17.510381
# 25    NDARZT011LBZ   7.760209
# 26    NDARKV482FU9  10.977298
# ...            ...        ...
# 2088  NDARAV069HGT  13.896189
# 2089  NDARZC497BFU  17.419917
# 2090  NDARDZ737LG9  13.031143
# 2094  NDARRT283RHB  10.712069
# 2095  NDARYG879ZM4  13.701346
#
# [513 rows x 2 columns]

# %% [markdown]
# # Power Sepectrum Cluster data

# %%
### Extract relevant info from the power spectral density of EEG data

## Front part of the skull

# Left front of the skull
df_psd_cluster_lfront = df_psd_cluster.filter(regex='lfront')
df_psd_cluster_lfront_eyesclosed = pd.concat([df_psd_cluster['id'], df_psd_cluster_lfront.filter(regex='eyesclosed')], axis=1)
df_psd_cluster_lfront_eyesopen = pd.concat([df_psd_cluster['id'], df_psd_cluster_lfront.filter(regex='eyesopen')], axis=1)

df_psd_cluster_lfront_eyesclosed.rename(columns={'id': 'Patient_ID'}, inplace=True)
df_psd_cluster_lfront_eyesopen.rename(columns={'id': 'Patient_ID'}, inplace=True)

# Middle front of the skull
df_psd_cluster_mfront = df_psd_cluster.filter(regex='mfront')
df_psd_cluster_mfront_eyesclosed = pd.concat([df_psd_cluster['id'], df_psd_cluster_mfront.filter(regex='eyesclosed')], axis=1)
df_psd_cluster_mfront_eyesopen = pd.concat([df_psd_cluster['id'], df_psd_cluster_mfront.filter(regex='eyesopen')], axis=1)

df_psd_cluster_mfront_eyesclosed.rename(columns={'id': 'Patient_ID'}, inplace=True)
df_psd_cluster_mfront_eyesopen.rename(columns={'id': 'Patient_ID'}, inplace=True)

# Right front of the skull
df_psd_cluster_rfront = df_psd_cluster.filter(regex='rfront')
df_psd_cluster_rfront_eyesclosed = pd.concat([df_psd_cluster['id'], df_psd_cluster_rfront.filter(regex='eyesclosed')], axis=1)
df_psd_cluster_rfront_eyesopen = pd.concat([df_psd_cluster['id'], df_psd_cluster_rfront.filter(regex='eyesopen')], axis=1)

df_psd_cluster_rfront_eyesclosed.rename(columns={'id': 'Patient_ID'}, inplace=True)
df_psd_cluster_rfront_eyesopen.rename(columns={'id': 'Patient_ID'}, inplace=True)

## Parietal part of the skull

# Left parietal part of the skull
df_psd_cluster_lpari = df_psd_cluster.filter(regex='lpari')
df_psd_cluster_lpari_eyesclosed = pd.concat([df_psd_cluster['id'], df_psd_cluster_lpari.filter(regex='eyesclosed')], axis=1)
df_psd_cluster_lpari_eyesopen = pd.concat([df_psd_cluster['id'], df_psd_cluster_lpari.filter(regex='eyesopen')], axis=1)

df_psd_cluster_lpari_eyesclosed.rename(columns={'id': 'Patient_ID'}, inplace=True)
df_psd_cluster_lpari_eyesopen.rename(columns={'id': 'Patient_ID'}, inplace=True)

# Middle parietal part of the skull
df_psd_cluster_mpari = df_psd_cluster.filter(regex='mpari')
df_psd_cluster_mpari_eyesclosed = pd.concat([df_psd_cluster['id'], df_psd_cluster_mpari.filter(regex='eyesclosed')], axis=1)
df_psd_cluster_mpari_eyesopen = pd.concat([df_psd_cluster['id'], df_psd_cluster_mpari.filter(regex='eyesopen')], axis=1)

df_psd_cluster_mpari_eyesclosed.rename(columns={'id': 'Patient_ID'}, inplace=True)
df_psd_cluster_mpari_eyesopen.rename(columns={'id': 'Patient_ID'}, inplace=True)

# Right parietal part of the skull
df_psd_cluster_rpari = df_psd_cluster.filter(regex='rpari')
df_psd_cluster_rpari_eyesclosed = pd.concat([df_psd_cluster['id'], df_psd_cluster_rpari.filter(regex='eyesclosed')], axis=1)
df_psd_cluster_rpari_eyesopen = pd.concat([df_psd_cluster['id'], df_psd_cluster_rpari.filter(regex='eyesopen')], axis=1)

df_psd_cluster_rpari_eyesclosed.rename(columns={'id': 'Patient_ID'}, inplace=True)
df_psd_cluster_rpari_eyesopen.rename(columns={'id': 'Patient_ID'}, inplace=True)

# %%
## Plot the power spectrums for first patient

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10))

freq = np.hstack((np.arange(1,58,0.5), np.arange(62.50,90.5,0.5)))

# Eyes open

power_lfront_eyesopen = np.asarray(df_psd_cluster_lfront_eyesopen.iloc[0,:])[1:]
power_mfront_eyesopen = np.asarray(df_psd_cluster_mfront_eyesopen.iloc[0,:])[1:]
power_rfront_eyesopen = np.asarray(df_psd_cluster_rfront_eyesopen.iloc[0,:])[1:]

power_lpari_eyesopen = np.asarray(df_psd_cluster_lpari_eyesopen.iloc[0,:])[1:]
power_mpari_eyesopen = np.asarray(df_psd_cluster_mpari_eyesopen.iloc[0,:])[1:]
power_rpari_eyesopen = np.asarray(df_psd_cluster_rpari_eyesopen.iloc[0,:])[1:]

plt.xlabel("Frequency")
plt.ylabel("Power")
ax1.set_title("Power Spectrum for eyes open of first patient")

ax1.plot(freq[:40], power_lfront_eyesopen[:40])
ax1.plot(freq[:40], power_mfront_eyesopen[:40])
ax1.plot(freq[:40], power_rfront_eyesopen[:40])

ax1.plot(freq[:40], power_lpari_eyesopen[:40])
ax1.plot(freq[:40], power_mpari_eyesopen[:40])
ax1.plot(freq[:40], power_rpari_eyesopen[:40])

ax1.legend(["Left front", "Middle front", "Right front", "Left pari", "Middle pari", "Right pari"])


# Eyes closed

power_lfront_eyesclosed = np.asarray(df_psd_cluster_lfront_eyesclosed.iloc[0,:])[1:]
power_mfront_eyesclosed = np.asarray(df_psd_cluster_mfront_eyesclosed.iloc[0,:])[1:]
power_rfront_eyesclosed = np.asarray(df_psd_cluster_rfront_eyesclosed.iloc[0,:])[1:]

power_lpari_eyesclosed = np.asarray(df_psd_cluster_lpari_eyesclosed.iloc[0,:])[1:]
power_mpari_eyesclosed = np.asarray(df_psd_cluster_mpari_eyesclosed.iloc[0,:])[1:]
power_rpari_eyesclosed = np.asarray(df_psd_cluster_rpari_eyesclosed.iloc[0,:])[1:]

plt.xlabel("Frequency")
plt.ylabel("Power")
ax2.set_title("Power Spectrum for eyes closed of first patient")

ax2.plot(freq[:40], power_lfront_eyesclosed[:40])
ax2.plot(freq[:40], power_mfront_eyesclosed[:40])
ax2.plot(freq[:40], power_rfront_eyesclosed[:40])

ax2.plot(freq[:40], power_lpari_eyesclosed[:40])
ax2.plot(freq[:40], power_mpari_eyesclosed[:40])
ax2.plot(freq[:40], power_rpari_eyesclosed[:40])

ax2.legend(["Left front", "Middle front", "Right front", "Left pari", "Middle pari", "Right pari"])

# %% [markdown]
# # Spectro Cluster Data

# %%
df_spectro_cluster.rename(columns={'id': 'Patient_ID'}, inplace=True)

for col in df_spectro_cluster.columns:
    print(col)
# Out:
# Patient_ID
# eyesclosed_fband_delta_absmean_lfront
# eyesclosed_fband_delta_absmean_mfront
# eyesclosed_fband_delta_absmean_rfront
# eyesclosed_fband_delta_absmean_lpari
# eyesclosed_fband_delta_absmean_mpari
# eyesclosed_fband_delta_absmean_rpari
# eyesclosed_fband_delta_relmean_lfront
# eyesclosed_fband_delta_relmean_mfront
# eyesclosed_fband_delta_relmean_rfront
# eyesclosed_fband_delta_relmean_lpari
# eyesclosed_fband_delta_relmean_mpari
# eyesclosed_fband_delta_relmean_rpari
# eyesclosed_fband_theta_absmean_lfront
# eyesclosed_fband_theta_absmean_mfront
# eyesclosed_fband_theta_absmean_rfront
# eyesclosed_fband_theta_absmean_lpari
# eyesclosed_fband_theta_absmean_mpari
# eyesclosed_fband_theta_absmean_rpari
# eyesclosed_fband_theta_relmean_lfront
# eyesclosed_fband_theta_relmean_mfront
# eyesclosed_fband_theta_relmean_rfront
# eyesclosed_fband_theta_relmean_lpari
# eyesclosed_fband_theta_relmean_mpari
# eyesclosed_fband_theta_relmean_rpari
# eyesclosed_fband_alpha_absmean_lfront
# eyesclosed_fband_alpha_absmean_mfront
# eyesclosed_fband_alpha_absmean_rfront
# eyesclosed_fband_alpha_absmean_lpari
# eyesclosed_fband_alpha_absmean_mpari
# eyesclosed_fband_alpha_absmean_rpari
# eyesclosed_fband_alpha_relmean_lfront
# eyesclosed_fband_alpha_relmean_mfront
# eyesclosed_fband_alpha_relmean_rfront
# eyesclosed_fband_alpha_relmean_lpari
# eyesclosed_fband_alpha_relmean_mpari
# eyesclosed_fband_alpha_relmean_rpari
# eyesclosed_fband_beta_absmean_lfront
# eyesclosed_fband_beta_absmean_mfront
# eyesclosed_fband_beta_absmean_rfront
# eyesclosed_fband_beta_absmean_lpari
# eyesclosed_fband_beta_absmean_mpari
# eyesclosed_fband_beta_absmean_rpari
# eyesclosed_fband_beta_relmean_lfront
# eyesclosed_fband_beta_relmean_mfront
# eyesclosed_fband_beta_relmean_rfront
# eyesclosed_fband_beta_relmean_lpari
# eyesclosed_fband_beta_relmean_mpari
# eyesclosed_fband_beta_relmean_rpari
# eyesclosed_fband_gamma_absmean_lfront
# eyesclosed_fband_gamma_absmean_mfront
# eyesclosed_fband_gamma_absmean_rfront
# eyesclosed_fband_gamma_absmean_lpari
# eyesclosed_fband_gamma_absmean_mpari
# eyesclosed_fband_gamma_absmean_rpari
# eyesclosed_fband_gamma_relmean_lfront
# eyesclosed_fband_gamma_relmean_mfront
# eyesclosed_fband_gamma_relmean_rfront
# eyesclosed_fband_gamma_relmean_lpari
# eyesclosed_fband_gamma_relmean_mpari
# eyesclosed_fband_gamma_relmean_rpari
# eyesclosed_alphapeak_max_freq
# eyesclosed_alphapeak_max_amplitude
# eyesclosed_alphapeak_derivative_freq
# eyesclosed_alphapeak_derivative_amplitude
# eyesclosed_alphapeak_gravity_freq
# eyesclosed_alphapeak_gravity_amplitude
# eyesclosed_indfband_theta_absmean_lfront
# eyesclosed_indfband_theta_absmean_mfront
# eyesclosed_indfband_theta_absmean_rfront
# eyesclosed_indfband_theta_absmean_lpari
# eyesclosed_indfband_theta_absmean_mpari
# eyesclosed_indfband_theta_absmean_rpari
# eyesclosed_indfband_theta_relmean_lfront
# eyesclosed_indfband_theta_relmean_mfront
# eyesclosed_indfband_theta_relmean_rfront
# eyesclosed_indfband_theta_relmean_lpari
# eyesclosed_indfband_theta_relmean_mpari
# eyesclosed_indfband_theta_relmean_rpari
# eyesclosed_indfband_lower1alpha_absmean_lfront
# eyesclosed_indfband_lower1alpha_absmean_mfront
# eyesclosed_indfband_lower1alpha_absmean_rfront
# eyesclosed_indfband_lower1alpha_absmean_lpari
# eyesclosed_indfband_lower1alpha_absmean_mpari
# eyesclosed_indfband_lower1alpha_absmean_rpari
# eyesclosed_indfband_lower1alpha_relmean_lfront
# eyesclosed_indfband_lower1alpha_relmean_mfront
# eyesclosed_indfband_lower1alpha_relmean_rfront
# eyesclosed_indfband_lower1alpha_relmean_lpari
# eyesclosed_indfband_lower1alpha_relmean_mpari
# eyesclosed_indfband_lower1alpha_relmean_rpari
# eyesclosed_indfband_lower2alpha_absmean_lfront
# eyesclosed_indfband_lower2alpha_absmean_mfront
# eyesclosed_indfband_lower2alpha_absmean_rfront
# eyesclosed_indfband_lower2alpha_absmean_lpari
# eyesclosed_indfband_lower2alpha_absmean_mpari
# eyesclosed_indfband_lower2alpha_absmean_rpari
# eyesclosed_indfband_lower2alpha_relmean_lfront
# eyesclosed_indfband_lower2alpha_relmean_mfront
# eyesclosed_indfband_lower2alpha_relmean_rfront
# eyesclosed_indfband_lower2alpha_relmean_lpari
# eyesclosed_indfband_lower2alpha_relmean_mpari
# eyesclosed_indfband_lower2alpha_relmean_rpari
# eyesclosed_indfband_upperalpha_absmean_lfront
# eyesclosed_indfband_upperalpha_absmean_mfront
# eyesclosed_indfband_upperalpha_absmean_rfront
# eyesclosed_indfband_upperalpha_absmean_lpari
# eyesclosed_indfband_upperalpha_absmean_mpari
# eyesclosed_indfband_upperalpha_absmean_rpari
# eyesclosed_indfband_upperalpha_relmean_lfront
# eyesclosed_indfband_upperalpha_relmean_mfront
# eyesclosed_indfband_upperalpha_relmean_rfront
# eyesclosed_indfband_upperalpha_relmean_lpari
# eyesclosed_indfband_upperalpha_relmean_mpari
# eyesclosed_indfband_upperalpha_relmean_rpari
# eyesclosed_indfband_beta_absmean_lfront
# eyesclosed_indfband_beta_absmean_mfront
# eyesclosed_indfband_beta_absmean_rfront
# eyesclosed_indfband_beta_absmean_lpari
# eyesclosed_indfband_beta_absmean_mpari
# eyesclosed_indfband_beta_absmean_rpari
# eyesclosed_indfband_beta_relmean_lfront
# eyesclosed_indfband_beta_relmean_mfront
# eyesclosed_indfband_beta_relmean_rfront
# eyesclosed_indfband_beta_relmean_lpari
# eyesclosed_indfband_beta_relmean_mpari
# eyesclosed_indfband_beta_relmean_rpari
# eyesclosed_fooof_aperiodic_intercept_lfront
# eyesclosed_fooof_aperiodic_intercept_mfront
# eyesclosed_fooof_aperiodic_intercept_rfront
# eyesclosed_fooof_aperiodic_intercept_lpari
# eyesclosed_fooof_aperiodic_intercept_mpari
# eyesclosed_fooof_aperiodic_intercept_rpari
# eyesclosed_fooof_aperiodic_slope_lfront
# eyesclosed_fooof_aperiodic_slope_mfront
# eyesclosed_fooof_aperiodic_slope_rfront
# eyesclosed_fooof_aperiodic_slope_lpari
# eyesclosed_fooof_aperiodic_slope_mpari
# eyesclosed_fooof_aperiodic_slope_rpari
# eyesclosed_fooof_peak_freq_lfront
# eyesclosed_fooof_peak_freq_mfront
# eyesclosed_fooof_peak_freq_rfront
# eyesclosed_fooof_peak_freq_lpari
# eyesclosed_fooof_peak_freq_mpari
# eyesclosed_fooof_peak_freq_rpari
# eyesclosed_fooof_peak_amplitude_lfront
# eyesclosed_fooof_peak_amplitude_mfront
# eyesclosed_fooof_peak_amplitude_rfront
# eyesclosed_fooof_peak_amplitude_lpari
# eyesclosed_fooof_peak_amplitude_mpari
# eyesclosed_fooof_peak_amplitude_rpari
# eyesopen_fband_delta_absmean_lfront
# eyesopen_fband_delta_absmean_mfront
# eyesopen_fband_delta_absmean_rfront
# eyesopen_fband_delta_absmean_lpari
# eyesopen_fband_delta_absmean_mpari
# eyesopen_fband_delta_absmean_rpari
# eyesopen_fband_delta_relmean_lfront
# eyesopen_fband_delta_relmean_mfront
# eyesopen_fband_delta_relmean_rfront
# eyesopen_fband_delta_relmean_lpari
# eyesopen_fband_delta_relmean_mpari
# eyesopen_fband_delta_relmean_rpari
# eyesopen_fband_theta_absmean_lfront
# eyesopen_fband_theta_absmean_mfront
# eyesopen_fband_theta_absmean_rfront
# eyesopen_fband_theta_absmean_lpari
# eyesopen_fband_theta_absmean_mpari
# eyesopen_fband_theta_absmean_rpari
# eyesopen_fband_theta_relmean_lfront
# eyesopen_fband_theta_relmean_mfront
# eyesopen_fband_theta_relmean_rfront
# eyesopen_fband_theta_relmean_lpari
# eyesopen_fband_theta_relmean_mpari
# eyesopen_fband_theta_relmean_rpari
# eyesopen_fband_alpha_absmean_lfront
# eyesopen_fband_alpha_absmean_mfront
# eyesopen_fband_alpha_absmean_rfront
# eyesopen_fband_alpha_absmean_lpari
# eyesopen_fband_alpha_absmean_mpari
# eyesopen_fband_alpha_absmean_rpari
# eyesopen_fband_alpha_relmean_lfront
# eyesopen_fband_alpha_relmean_mfront
# eyesopen_fband_alpha_relmean_rfront
# eyesopen_fband_alpha_relmean_lpari
# eyesopen_fband_alpha_relmean_mpari
# eyesopen_fband_alpha_relmean_rpari
# eyesopen_fband_beta_absmean_lfront
# eyesopen_fband_beta_absmean_mfront
# eyesopen_fband_beta_absmean_rfront
# eyesopen_fband_beta_absmean_lpari
# eyesopen_fband_beta_absmean_mpari
# eyesopen_fband_beta_absmean_rpari
# eyesopen_fband_beta_relmean_lfront
# eyesopen_fband_beta_relmean_mfront
# eyesopen_fband_beta_relmean_rfront
# eyesopen_fband_beta_relmean_lpari
# eyesopen_fband_beta_relmean_mpari
# eyesopen_fband_beta_relmean_rpari
# eyesopen_fband_gamma_absmean_lfront
# eyesopen_fband_gamma_absmean_mfront
# eyesopen_fband_gamma_absmean_rfront
# eyesopen_fband_gamma_absmean_lpari
# eyesopen_fband_gamma_absmean_mpari
# eyesopen_fband_gamma_absmean_rpari
# eyesopen_fband_gamma_relmean_lfront
# eyesopen_fband_gamma_relmean_mfront
# eyesopen_fband_gamma_relmean_rfront
# eyesopen_fband_gamma_relmean_lpari
# eyesopen_fband_gamma_relmean_mpari
# eyesopen_fband_gamma_relmean_rpari
# eyesopen_alphapeak_max_freq
# eyesopen_alphapeak_max_amplitude
# eyesopen_alphapeak_derivative_freq
# eyesopen_alphapeak_derivative_amplitude
# eyesopen_alphapeak_gravity_freq
# eyesopen_alphapeak_gravity_amplitude
# eyesopen_indfband_theta_absmean_lfront
# eyesopen_indfband_theta_absmean_mfront
# eyesopen_indfband_theta_absmean_rfront
# eyesopen_indfband_theta_absmean_lpari
# eyesopen_indfband_theta_absmean_mpari
# eyesopen_indfband_theta_absmean_rpari
# eyesopen_indfband_theta_relmean_lfront
# eyesopen_indfband_theta_relmean_mfront
# eyesopen_indfband_theta_relmean_rfront
# eyesopen_indfband_theta_relmean_lpari
# eyesopen_indfband_theta_relmean_mpari
# eyesopen_indfband_theta_relmean_rpari
# eyesopen_indfband_lower1alpha_absmean_lfront
# eyesopen_indfband_lower1alpha_absmean_mfront
# eyesopen_indfband_lower1alpha_absmean_rfront
# eyesopen_indfband_lower1alpha_absmean_lpari
# eyesopen_indfband_lower1alpha_absmean_mpari
# eyesopen_indfband_lower1alpha_absmean_rpari
# eyesopen_indfband_lower1alpha_relmean_lfront
# eyesopen_indfband_lower1alpha_relmean_mfront
# eyesopen_indfband_lower1alpha_relmean_rfront
# eyesopen_indfband_lower1alpha_relmean_lpari
# eyesopen_indfband_lower1alpha_relmean_mpari
# eyesopen_indfband_lower1alpha_relmean_rpari
# eyesopen_indfband_lower2alpha_absmean_lfront
# eyesopen_indfband_lower2alpha_absmean_mfront
# eyesopen_indfband_lower2alpha_absmean_rfront
# eyesopen_indfband_lower2alpha_absmean_lpari
# eyesopen_indfband_lower2alpha_absmean_mpari
# eyesopen_indfband_lower2alpha_absmean_rpari
# eyesopen_indfband_lower2alpha_relmean_lfront
# eyesopen_indfband_lower2alpha_relmean_mfront
# eyesopen_indfband_lower2alpha_relmean_rfront
# eyesopen_indfband_lower2alpha_relmean_lpari
# eyesopen_indfband_lower2alpha_relmean_mpari
# eyesopen_indfband_lower2alpha_relmean_rpari
# eyesopen_indfband_upperalpha_absmean_lfront
# eyesopen_indfband_upperalpha_absmean_mfront
# eyesopen_indfband_upperalpha_absmean_rfront
# eyesopen_indfband_upperalpha_absmean_lpari
# eyesopen_indfband_upperalpha_absmean_mpari
# eyesopen_indfband_upperalpha_absmean_rpari
# eyesopen_indfband_upperalpha_relmean_lfront
# eyesopen_indfband_upperalpha_relmean_mfront
# eyesopen_indfband_upperalpha_relmean_rfront
# eyesopen_indfband_upperalpha_relmean_lpari
# eyesopen_indfband_upperalpha_relmean_mpari
# eyesopen_indfband_upperalpha_relmean_rpari
# eyesopen_indfband_beta_absmean_lfront
# eyesopen_indfband_beta_absmean_mfront
# eyesopen_indfband_beta_absmean_rfront
# eyesopen_indfband_beta_absmean_lpari
# eyesopen_indfband_beta_absmean_mpari
# eyesopen_indfband_beta_absmean_rpari
# eyesopen_indfband_beta_relmean_lfront
# eyesopen_indfband_beta_relmean_mfront
# eyesopen_indfband_beta_relmean_rfront
# eyesopen_indfband_beta_relmean_lpari
# eyesopen_indfband_beta_relmean_mpari
# eyesopen_indfband_beta_relmean_rpari
# eyesopen_fooof_aperiodic_intercept_lfront
# eyesopen_fooof_aperiodic_intercept_mfront
# eyesopen_fooof_aperiodic_intercept_rfront
# eyesopen_fooof_aperiodic_intercept_lpari
# eyesopen_fooof_aperiodic_intercept_mpari
# eyesopen_fooof_aperiodic_intercept_rpari
# eyesopen_fooof_aperiodic_slope_lfront
# eyesopen_fooof_aperiodic_slope_mfront
# eyesopen_fooof_aperiodic_slope_rfront
# eyesopen_fooof_aperiodic_slope_lpari
# eyesopen_fooof_aperiodic_slope_mpari
# eyesopen_fooof_aperiodic_slope_rpari
# eyesopen_fooof_peak_freq_lfront
# eyesopen_fooof_peak_freq_mfront
# eyesopen_fooof_peak_freq_rfront
# eyesopen_fooof_peak_freq_lpari
# eyesopen_fooof_peak_freq_mpari
# eyesopen_fooof_peak_freq_rpari
# eyesopen_fooof_peak_amplitude_lfront
# eyesopen_fooof_peak_amplitude_mfront
# eyesopen_fooof_peak_amplitude_rfront
# eyesopen_fooof_peak_amplitude_lpari
# eyesopen_fooof_peak_amplitude_mpari
# eyesopen_fooof_peak_amplitude_rpari

# %% [markdown]
# # Aggregation of data

# %%
df_psd_cluster.rename(columns={'id': 'Patient_ID'}, inplace=True)
df_spectro_cluster.rename(columns={'id': 'Patient_ID'}, inplace=True)

df_psd_spectro_cluster = pd.merge(df_psd_cluster, df_spectro_cluster, on='Patient_ID')
df_psd_spectro_cluster_label = pd.merge(y_labels, df_psd_spectro_cluster, on='Patient_ID')

df_psd_spectro_cluster_label.dropna(inplace=True)

# %%
# Define Train and Test data 
total_samples = len(df_psd_spectro_cluster_label.index)
nsamples_test = int(0.1*total_samples)
df_psd_spectro_cluster_label = df_psd_spectro_cluster_label.sample(frac=1).reset_index(drop=True)

test = df_psd_spectro_cluster_label.iloc[:nsamples_test]
X_test = test.drop(['Patient_ID', 'Age'], axis=1)
y_test = test[['Age']]

train = df_psd_spectro_cluster_label.iloc[nsamples_test:]
X_train = train.drop(['Patient_ID', 'Age'], axis=1)
y_train = train[['Age']]

# %% [markdown]
# # Feature selection by correlation

# %%
corr = X_train.corrwith(y_train['Age'], axis=0, method='pearson')
feature_select = pd.DataFrame(corr.iloc[(-corr.abs()).argsort()][:20])
best_feature_names = feature_select.index.values
feature_select
# Out:
#                                                     0
# eyesclosed_fband_delta_relmean_mfront       -0.653330
# eyesclosed_indfband_theta_relmean_mfront    -0.641694
# eyesclosed_indfband_theta_relmean_lfront    -0.632360
# eyesclosed_fband_delta_relmean_lfront       -0.625696
# eyesclosed_indfband_theta_relmean_rfront    -0.624286
# eyesclosed_fband_delta_relmean_rfront       -0.611431
# eyesclosed_indfband_theta_relmean_mpari     -0.592619
# eyesclosed_indfband_theta_relmean_rpari     -0.576318
# eyesclosed_indfband_theta_relmean_lpari     -0.570610
# eyesopen_indfband_theta_relmean_mfront      -0.568865
# eyesopen_indfband_theta_relmean_lfront      -0.563724
# eyesopen_fband_beta_relmean_mpari            0.562196
# eyesclosed_fband_alpha_relmean_mfront        0.561983
# eyesopen_indfband_theta_relmean_rfront      -0.559343
# eyesopen_fband_beta_relmean_lpari            0.555934
# eyesclosed_fband_delta_relmean_rpari        -0.555867
# eyesopen_indfband_lower1alpha_relmean_rpari -0.555320
# eyesclosed_fband_delta_relmean_mpari        -0.553246
# eyesclosed_fband_delta_relmean_lpari        -0.552244
# eyesopen_fband_delta_relmean_mfront         -0.547780

# %%
X_train_feature_extracted = X_train[best_feature_names]
X_test_feature_extracted = X_test[best_feature_names]

# %% [markdown]
# # Linear Regression

# %%
# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(X_train_feature_extracted, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test_feature_extracted)

# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(y_test, y_pred))
# Out:
# Coefficients:
#  [[-0.75649887  0.69961658 -0.73294857 -0.03042757 -0.76312288  0.17595484
#   -2.18068336  1.29661807  0.85700881 -0.01476713  0.32035925  3.60190568
#    0.09742369  0.15066608  0.74280549 -0.10743709 -1.65189602  0.53127087
#   -0.02982547 -0.07965275]]
# Mean squared error: 6.39
# Coefficient of determination: 0.50
