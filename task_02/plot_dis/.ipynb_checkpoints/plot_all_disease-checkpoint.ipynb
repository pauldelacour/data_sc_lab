# %%
cd ../../task_01/pipelines
# Out:
# /Users/pldelacour/Documents/PL_Ecole/data_sc_lab/data_sc_lab/task_01/pipelines

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from ipynb.fs.full.tool_functions import *
from yellowbrick.regressor import AlphaSelection
from  sklearn.metrics import mean_squared_error

# %%
df_beha = pd.read_csv('../../../data/Behavioral/AllData.csv')#, nrows=1000)

df_psd_cluster = pd.read_csv("../../../data/EEG/RestingEEG_PSD_Cluster.csv") #, nrows=1000)
df_psd_channel = pd.read_csv("../../../data/EEG/RestingEEG_PSD_Channel.csv") #, nrows=5)
df_spectro_cluster = pd.read_csv("../../../data/EEG/RestingEEG_Spectro_Cluster.csv") #, nrows=1000)
df_spectro_channel = pd.read_csv("../../../data/EEG/RestingEEG_Spectro_Channel.csv") #, nrows=5)

df_microstate = pd.read_csv("../../../data/EEG/RestingEEG_Microstates.csv") #, nrows=5)
# Out:
# /Users/pldelacour/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (66,68,80,81,82,83,84,95,96,97,98,99,110,111,112,113,114,125,126,127,128,129,140,141,142,144,155,156,157,159,932,933,934,935,936,937,938,939,940,941,942,943,944,945,946,947,948,949,950,951,952,953,954,955,956,957,958,959,960,961,962,963,964,965,966,967,968,969,970,971,972,973,974,975,976,977,978,979,980,981,982,983,984,985,986,987,988,989,990,991,992,993,994,995,996,997,998,999,1000,1001,1002,1003,1004,1005,1006,1007,1008,1009,1010,1011,1012,1013,1014,1015,1016,1017,1018,1019,1020,1021,1022,1023,1024,1025,1026,1027,1028,1029,1030,1031,1032,1033,1034,1035,1036,1037,1038,1039,1040,1041,1042,1043,1044,1045,1046,1047,1048,1049,1050,1051,1052,1053,1054,1055,1056,1057,1058,1059,1060,1061,1062,1063,1064,1065,1066,1067,1068,1069,1070,1071,1072,1073,1074,1075,1076,1077,1078,1079,1080,1081,1082,1083,1084,1085,1086,1087,1088,1089,1090,1091,1092,1093,1094,1095,1096,1097,1098,1099,
# ...

# %%
disease = df_beha['DX_01'].unique()
y_labels = df_beha[["Patient_ID", "Age", "DX_01"]]
aut_bin = (df_beha['DX_01'].str.contains("Autism Spectrum Disorder") == True)*1.0
#df_beha['autism'] = aut_bin

# %%
df_beha.pivot_table(index=['DX_01'], aggfunc='size')
# Out:
# DX_01
#                                                                          2
# ADHD-Combined Type                                                     387
# ADHD-Hyperactive/Impulsive Type                                         49
# ADHD-Inattentive Type                                                  295
# Acute Stress Disorder                                                    2
# Adjustment Disorders                                                    16
# Agoraphobia                                                              1
# Autism Spectrum Disorder                                               164
# Bipolar I Disorder                                                       3
# Bipolar II Disorder                                                      3
# Borderline Intellectual Functioning                                      7
# Cannabis Use Disorder                                                    1
# ...

# %%
#Taking only disease with more than 50 samples.
ind = df_beha.pivot_table(index=['DX_01'], aggfunc='size')
#ds = np.array(ind[ind.values].index)


ds = np.array(ind[ind>=50].index)
ds_map = { i:x for i,x in enumerate(ds)}

#Build the y vector from the disease
y_labels = df_beha[["Patient_ID", "Age", "DX_01" ]]

y = 100*np.ones(len(y_labels["DX_01"]))
for i in range(len(ds)):
    ind = (y_labels["DX_01"].str.contains(ds_map[i]) == True)
    y[ind] = i
    
#Print the number of samples per class
for i in range(8) : 
    print(ds_map[i] , np.sum(y==i))
# Out:
# ADHD-Combined Type 387
# ADHD-Inattentive Type 295
# Autism Spectrum Disorder 164
# Generalized Anxiety Disorder 70
# Major Depressive Disorder 60
# No Diagnosis Given 235
# No Diagnosis Given: Incomplete Eval 278
# Other Specified Attention-Deficit/Hyperactivity Disorder 53

# %%
253+278
#len(y)
# Out:
# 531

# %%
#ADHD Type :
#-ADHD-Inattentive Type
#-ADHD-Hyperactive/Impulsive Type
#-ADHD-Combined Type

y_labels = df_beha[["Patient_ID", "Age", "DX_01" ]]

y = 100*np.ones(len(y_labels["DX_01"]))
for i in range(len(ds)):
    ind = (y_labels["DX_01"].str.contains(ds_map[i]) == True)
    y[ind] = i

disease = df_beha['DX_01'].unique()
df_dis = df_beha[["Patient_ID", "Age"]]
df_dis['disease'] = y

df_spectro_cluster.rename(columns={'id': 'Patient_ID'}, inplace=True)
# Aggregate with label
df_dis_spectro = pd.merge(df_dis, df_spectro_cluster, on='Patient_ID')
#Replace NAN
df_dis_spectro = fill_with_median(df_dis_spectro)


X = df_dis_spectro.drop(['Patient_ID', 'disease'], axis=1)
y =  df_dis_spectro[['disease']]

#X = np.array(X)

#Scaling features  
scaler = StandardScaler()
scaler.fit(X)
X = pd.DataFrame(scaler.transform(X), columns=X.columns, index=X.index)
X = np.array(X)
y = np.array(y)
# Out:
# /Users/pldelacour/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app

# %% [markdown]
# ## PCA of All disease

# %%
cd ../../task_02/plot_dis
# Out:
# /Users/pldelacour/Documents/PL_Ecole/data_sc_lab/data_sc_lab/task_02/plot_dis

# %%
from sklearn.decomposition import PCA
from sklearn.decomposition import FastICA

# %%
ds_map.keys()
target_names = []
for i in ds_map.values() :
    target_names.append(i)
target_names
# Out:
# ['ADHD-Combined Type',
#  'ADHD-Inattentive Type',
#  'Autism Spectrum Disorder',
#  'Generalized Anxiety Disorder',
#  'Major Depressive Disorder',
#  'No Diagnosis Given',
#  'No Diagnosis Given: Incomplete Eval',
#  'Other Specified Attention-Deficit/Hyperactivity Disorder',
#  'Social Anxiety (Social Phobia)',
#  'Specific Learning Disorder with Impairment in Reading']

# %%
#pca = PCA(n_components=2)
#X_r = pca.fit(X).transform(X)

pca = FastICA(n_components=2)
X_r = pca.fit(X).transform(X)


#print(X_r)
#print(X_r.shape)

target_names = []
for i in ds_map.values() :
    target_names.append(i)

keys = []
for i in ds_map.keys() :
    keys.append(i)

    
# Percentage of variance explained for each components
#print('explained variance ratio (first two components): %s'
#      % str(pca.explained_variance_ratio_))

#plt.figure()
plt.figure(figsize=(8, 8))
colors = ['navy', 'darkorange' , 'green' , 'purple', 'chocolate' , 'lightslategrey'  , 'hotpink' , 'crimson']
lw = 1

for color, i, target_name in zip(colors, keys, target_names):
    ##
    #print(color, i , target_name)
    #X_r[y == i, 0]
    ##
    plt.scatter(X_r[(y==i).flatten(), 0], X_r[(y==i).flatten(), 1], color=color, alpha=.8, lw=lw,
                label=target_name)
#plt.legend(loc='best', shadow=False, scatterpoints=1)
plt.legend( bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title('ICA of all diseases')


plt.show
#plt.savefig('pca_all_disease.png')
#filename = 'pca_all_disease.png'
filename = 'ica_all_diseases.png'
plt.savefig(filename, bbox_inches = 'tight')

# %% [markdown]
# ## Make the same thing for clusters :

# %%
import itertools

# %%
'''
ind1 = df_beha.pivot_table(index=['DX_01'], aggfunc='size')>=10
size1 = np.array(df_beha.pivot_table(index=['DX_01'], aggfunc='size')[ind1.values].index)
ind2 = df_beha.pivot_table(index = ['DX_02'] , aggfunc ='size')>=10
size2 = np.array(df_beha.pivot_table(index = ['DX_02'] , aggfunc = 'size')[ind2.values].index)
ind3 = df_beha.pivot_table(index = ['DX_03'] , aggfunc ='size')>=10
size3 = np.array(df_beha.pivot_table(index = ['DX_03'] , aggfunc = 'size')[ind3.values].index)
ind4 = df_beha.pivot_table(index = ['DX_04'] , aggfunc ='size')>=10
size4 = np.array(df_beha.pivot_table(index = ['DX_04'] , aggfunc = 'size')[ind4.values].index)


size1 = df_beha['DX_01'].unique()
size2 = df_beha['DX_02'].unique()
size3 = df_beha['DX_03'].unique()
size4 = df_beha['DX_04'].unique()

ds = list(itertools.product(size1,size2 , size3 , size4))
ds_map = { (i+1):x for i,x in enumerate(ds)}
#ds_map
'''
# Out:
# "\nind1 = df_beha.pivot_table(index=['DX_01'], aggfunc='size')>=10\nsize1 = np.array(df_beha.pivot_table(index=['DX_01'], aggfunc='size')[ind1.values].index)\nind2 = df_beha.pivot_table(index = ['DX_02'] , aggfunc ='size')>=10\nsize2 = np.array(df_beha.pivot_table(index = ['DX_02'] , aggfunc = 'size')[ind2.values].index)\nind3 = df_beha.pivot_table(index = ['DX_03'] , aggfunc ='size')>=10\nsize3 = np.array(df_beha.pivot_table(index = ['DX_03'] , aggfunc = 'size')[ind3.values].index)\nind4 = df_beha.pivot_table(index = ['DX_04'] , aggfunc ='size')>=10\nsize4 = np.array(df_beha.pivot_table(index = ['DX_04'] , aggfunc = 'size')[ind4.values].index)\n\n\nsize1 = df_beha['DX_01'].unique()\nsize2 = df_beha['DX_02'].unique()\nsize3 = df_beha['DX_03'].unique()\nsize4 = df_beha['DX_04'].unique()\n\nds = list(itertools.product(size1,size2 , size3 , size4))\nds_map = { (i+1):x for i,x in enumerate(ds)}\n#ds_map\n"

# %%
'''

#make tuples for different combinations of disease : 

#ds = [{values[0], values[1] , values[2] , values[3]} for values in list(itertools.product(size1,size2 , size3 , size4))]
ds = list(itertools.product(size1,size2 , size3 , size4))
ds_map = { (i+1):x for i,x in enumerate(ds)}
'''
# Out:
# '\n\n#make tuples for different combinations of disease : \n\n#ds = [{values[0], values[1] , values[2] , values[3]} for values in list(itertools.product(size1,size2 , size3 , size4))]\nds = list(itertools.product(size1,size2 , size3 , size4))\nds_map = { (i+1):x for i,x in enumerate(ds)}\n'

# %%
dis_tot = df_beha[["Patient_ID", "Age", "DX_01" , "DX_02" , "DX_03" , "DX_04" ]]
dis_tot["DX_01"] = dis_tot["DX_01"].fillna('NAN')
dis_tot["DX_02"] = dis_tot["DX_02"].fillna('NAN')
dis_tot["DX_03"] = dis_tot["DX_03"].fillna('NAN')
dis_tot["DX_04"] = dis_tot["DX_04"].fillna('NAN')

disease_table1 = dis_tot.pivot_table(index=['DX_01'], aggfunc='size')
size1 = np.array(disease_table1[disease_table1 >=50].index)
disease_table2 = dis_tot.pivot_table(index=['DX_02'], aggfunc='size')
size2 = np.array(disease_table2[disease_table2 >=50].index)
disease_table3 = dis_tot.pivot_table(index=['DX_03'], aggfunc='size')
size3 = np.array(disease_table3[disease_table3 >=20].index)
disease_table4 = dis_tot.pivot_table(index=['DX_04'], aggfunc='size')
size4 = np.array(disease_table4[disease_table4 >=15].index)
print(size1)
print(size2)
print(size3)
print(size4)
# Out:
# ['ADHD-Combined Type' 'ADHD-Inattentive Type' 'Autism Spectrum Disorder'
#  'Generalized Anxiety Disorder' 'Major Depressive Disorder'
#  'No Diagnosis Given' 'No Diagnosis Given: Incomplete Eval'
#  'Other Specified Attention-Deficit/Hyperactivity Disorder'
#  'Social Anxiety (Social Phobia)'
#  'Specific Learning Disorder with Impairment in Reading']
# ['ADHD-Combined Type' 'ADHD-Inattentive Type' 'Autism Spectrum Disorder'
#  'Generalized Anxiety Disorder' 'Language Disorder' 'NAN'
#  'Specific Learning Disorder with Impairment in Reading']
# ['Autism Spectrum Disorder' 'Enuresis' 'Generalized Anxiety Disorder'
#  'Language Disorder' 'NAN' 'Separation Anxiety'
#  'Specific Learning Disorder with Impairment in Mathematics'
#  'Specific Learning Disorder with Impairment in Reading' 'Specific Phobia']
# ['Language Disorder' 'NAN' 'Specific Phobia']
# /Users/pldelacour/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# ...

# %%
ds = list(itertools.product(size1,size2 , size3 , size4))
ds_map = { (i+1):x for i,x in enumerate(ds)}

# %%
len(ds_map)
# Out:
# 1890

# %%
#y_labels = df_beha[["Patient_ID", "Age", "DX_01" , "DX_02" , "DX_03" , "DX_04" ]]
#y_labels["DX_01"] = y_labels["DX_01"].fillna('NAN')
y_labels = df_beha[["Patient_ID", "Age", "DX_01" , "DX_02" , "DX_03" , "DX_04" ]]
y_labels["DX_01"] = y_labels["DX_01"].fillna('NAN')
y_labels["DX_02"] = y_labels["DX_02"].fillna('NAN')
y_labels["DX_03"] = y_labels["DX_03"].fillna('NAN')
y_labels["DX_04"] = y_labels["DX_04"].fillna('NAN')

y = np.zeros(len(y_labels["DX_01"])) ## 0 corresponds to undifined label
for i in range(len(ds)):
    
    t = ds_map[i+1]
    ind1 = y_labels["DX_01"].str.contains(t[0])
    ind2 = y_labels["DX_02"].str.contains(t[1])
    ind3 = y_labels["DX_03"].str.contains(t[2])
    ind4 = y_labels["DX_04"].str.contains(t[3])
    ind_tot = ind1&ind2&ind3&ind4
    y[ind_tot] = i+1
# Out:
# /Users/pldelacour/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/pldelacour/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/pldelacour/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
for i in np.unique(y):
    if (i != 0) :
        count = np.sum(y==i)
    #    if count>=10 : 
        print(ds_map[i] ,count)
# Out:
# ('ADHD-Combined Type', 'ADHD-Combined Type', 'NAN', 'NAN') 1
# ('ADHD-Combined Type', 'Autism Spectrum Disorder', 'Language Disorder', 'NAN') 2
# ('ADHD-Combined Type', 'Autism Spectrum Disorder', 'NAN', 'NAN') 18
# ('ADHD-Combined Type', 'Autism Spectrum Disorder', 'Specific Learning Disorder with Impairment in Reading', 'NAN') 1
# ('ADHD-Combined Type', 'Autism Spectrum Disorder', 'Specific Learning Disorder with Impairment in Reading', 'Specific Phobia') 1
# ('ADHD-Combined Type', 'Autism Spectrum Disorder', 'Specific Phobia', 'Specific Phobia') 1
# ('ADHD-Combined Type', 'Generalized Anxiety Disorder', 'Autism Spectrum Disorder', 'NAN') 2
# ('ADHD-Combined Type', 'Generalized Anxiety Disorder', 'Language Disorder', 'NAN') 1
# ('ADHD-Combined Type', 'Generalized Anxiety Disorder', 'NAN', 'NAN') 9
# ('ADHD-Combined Type', 'Generalized Anxiety Disorder', 'Separation Anxiety', 'NAN') 1
# ...

# %%
#ADHD Type :
#-ADHD-Inattentive Type
#-ADHD-Hyperactive/Impulsive Type
#-ADHD-Combined Type


#disease = df_beha['DX_01'].unique()
df_dis = df_beha[["Patient_ID", "Age"]]
df_dis['disease'] = y

df_spectro_cluster.rename(columns={'id': 'Patient_ID'}, inplace=True)
# Aggregate with label
df_dis_spectro = pd.merge(df_dis, df_spectro_cluster, on='Patient_ID')
#Replace NAN
df_dis_spectro = fill_with_median(df_dis_spectro)

#Remove all 0-Disease in the y which corresponds to undefined disease
df_dis_spectro = df_dis_spectro.loc[df_dis_spectro.disease != 0 ,:]

X = df_dis_spectro.drop(['Patient_ID', 'disease'], axis=1)
y =  df_dis_spectro[['disease']]

#X = np.array(X)

#Scaling features  
scaler = StandardScaler()
scaler.fit(X)
X = pd.DataFrame(scaler.transform(X), columns=X.columns, index=X.index)
X = np.array(X)
y = np.array(y)
# Out:
# /Users/pldelacour/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
X.shape
#len(y)
# Out:
# (709, 301)

# %% [markdown]
# ## PCA

# %%
ds_map.keys()
target_names = []
for i in np.unique(y) :
    target_names.append(ds_map[i])
len(target_names)
# Out:
# 67

# %%
import random

# %%
#pca = PCA(n_components=2)
#X_r = pca.fit(X).transform(X)

pca = FastICA(n_components=2)
X_r = pca.fit(X).transform(X)


#print(X_r)
#print(X_r.shape)

target_names = []
for i in ds_map.values() :
    target_names.append(i)

keys = []
for i in np.unique(y) :
    keys.append(i)

    
# Percentage of variance explained for each components
#print('explained variance ratio (first two components): %s'
#      % str(pca.explained_variance_ratio_))

#plt.figure()
plt.figure(figsize=(8, 8))
#colors = ['navy', 'darkorange' , 'green' , 'purple', 'chocolate' , 'lightslategrey'  , 'hotpink' , 'crimson']
number_of_colors = len(np.unique(y))
colors = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])
             for i in range(number_of_colors)]
lw = 1

for color, i, target_name in zip(colors, keys, target_names):
    ##
    #print(color, i , target_name)
    #X_r[y == i, 0]
    ##
    plt.scatter(X_r[(y==i).flatten(), 0], X_r[(y==i).flatten(), 1], color=color, alpha=.8, lw=lw,
                label=target_name)
#plt.legend(loc='best', shadow=False, scatterpoints=1)
plt.legend( bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title('ICA of all group diseases')


plt.show
#plt.savefig('pca_all_disease.png')
filename = 'ica_all_group_disease.png'
plt.savefig(filename, bbox_inches = 'tight')

# %%
i = keys[0]
len(y==i)
# Out:
# 2096

# %%
X_r.shape
# Out:
# (1306, 2)
