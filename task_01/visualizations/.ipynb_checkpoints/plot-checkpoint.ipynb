# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_cluster = pd.read_csv("../../data/EEG/RestingEEG_PSD_Cluster.csv")
df_beha = pd.read_csv('../../data/Behavioral/AllData.csv')
# Out:
# /Users/pldelacour/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (66,68,80,81,82,83,84,95,96,97,98,99,110,111,112,113,114,125,126,127,128,129,140,141,142,144,155,156,157,159,932,933,934,935,936,937,938,939,940,941,942,943,944,945,946,947,948,949,950,951,952,953,954,955,956,957,958,959,960,961,962,963,964,965,966,967,968,969,970,971,972,973,974,975,976,977,978,979,980,981,982,983,984,985,986,987,988,989,990,991,992,993,994,995,996,997,998,999,1000,1001,1002,1003,1004,1005,1006,1007,1008,1009,1010,1011,1012,1013,1014,1015,1016,1017,1018,1019,1020,1021,1022,1023,1024,1025,1026,1027,1028,1029,1030,1031,1032,1033,1034,1035,1036,1037,1038,1039,1040,1041,1042,1043,1044,1045,1046,1047,1048,1049,1050,1051,1052,1053,1054,1055,1056,1057,1058,1059,1060,1061,1062,1063,1064,1065,1066,1067,1068,1069,1070,1071,1072,1073,1074,1075,1076,1077,1078,1079,1080,1081,1082,1083,1084,1085,1086,1087,1088,1089,1090,1091,1092,1093,1094,1095,1096,1097,1098,1099,
# ...

# %%
df_beha.head(5)
df_beha.columns
age = df_beha['Age']
age_rounded = np.round(age , 0)
age_rounded
# Out:
# 0        7.0
# 1        6.0
# 2       10.0
# 3       12.0
# 4       14.0
#         ...
# 2091     8.0
# 2092    10.0
# 2093    15.0
# 2094    11.0
# 2095    14.0
# Name: Age, Length: 2096, dtype: float64

# %%
plt.xlabel("Age")
plt.title("Age Distribution in the Data")
plt.hist(age_rounded, bins = 20)
# Out:
# (array([ 90., 193., 213., 252., 228., 203.,   0., 170., 143., 123., 126.,
#         103.,  94.,   0.,  68.,  39.,  19.,  15.,  12.,   5.]),
#  array([ 5.  ,  5.85,  6.7 ,  7.55,  8.4 ,  9.25, 10.1 , 10.95, 11.8 ,
#         12.65, 13.5 , 14.35, 15.2 , 16.05, 16.9 , 17.75, 18.6 , 19.45,
#         20.3 , 21.15, 22.  ]),
#  <a list of 20 Patch objects>)

# %%
x_train_beha = df_beha.loc[: , df_beha.columns != 'Age']
y_train = df_beha.loc[: , df_beha.columns == 'Age']

# %%
df_cluster.head(5)
# Out:
#              id  eyesclosed_psd_01dot00hz_lfront  \
# 0  NDARAA075AMK                        12.581212
# 1  NDARAA112DMH                        30.840888
# 2  NDARAA117NEJ                        15.834619
# 3  NDARAA948VFH                         4.844976
# 4  NDARAB348EWR                         5.549177
#
#    eyesclosed_psd_01dot00hz_mfront  eyesclosed_psd_01dot00hz_rfront  \
# 0                        13.449651                        11.075247
# 1                        13.742907                        10.534506
# 2                        21.863435                        16.166030
# 3                         7.907573                         6.850318
# 4                        10.895609                         8.379351
#
#    eyesclosed_psd_01dot00hz_lpari  eyesclosed_psd_01dot00hz_mpari  \
# 0                        9.108712                       18.642595
# 1                       14.630319                       15.270151
# ...

# %%
df_beha.head(5)
# Out:
#   Anonymized.ID Subject.Type Visit  Days.since.enrollment           EID  \
# 0     A00078864      UNKNOWN    V1                      0  NDARYM832PX3
# 1     A00078865      UNKNOWN    V1                      0  NDARNJ687DMC
# 2     A00078866      UNKNOWN    V1                      0  NDARRM363BXZ
# 3     A00078867      UNKNOWN    V1                      0  NDARUW586LLL
# 4     A00078868      UNKNOWN    V1                      0  NDARDC298NW4
#
#              START_DATE    Patient_ID  Enrollment.Year Enrollment.Season  Sex  \
# 0  1901-01-01T07:00:00Z  NDARYM832PX3             2015            Spring    1
# 1  1901-01-01T07:00:00Z  NDARNJ687DMC             2015            Spring    1
# 2  1901-01-01T07:00:00Z  NDARRM363BXZ             2015            Spring    0
# 3  1901-01-01T07:00:00Z  NDARUW586LLL             2015            Spring    1
# 4  1901-01-01T07:00:00Z  NDARDC298NW4             2015            Spring    0
#
# ...

# %%
min_a =  min(age)
max_a = max(age)
print(min_a)
print(max_a)
n_clust = 10
step = (max_a - min_a)/n_clust
age = np.array(df_beha['Age'])
feature = np.zeros(len(age))
for i in range(n_clust) :
    index = np.array(age>= (min_a + i*step)) * np.array(age < (min_a + (i+1)*step))
    index = np.array(index)
    feature[index] = i
print(feature)

df_beha['age_category'] = feature
# Out:
# 5.003878
# 21.854779
# [1. 0. 2. ... 6. 3. 5.]

# %%
renamed_beha  = df_beha.rename(columns = {'Patient_ID' : 'True_ID'}, inplace=False)
renamed_cluster = df_cluster.rename(columns = {'id' : 'True_ID'} , inplace = False)

# %%
len(df_beha['Age'])
# Out:
# 2096

# %%
df = pd.merge(renamed_beha[['Age' , 'True_ID']], renamed_cluster, on='True_ID')
labels = [0,1,2,3]
df['age_cat'] = pd.cut(df['Age'] , [0.0 , 5.0, 10.0 , 15.0 , 25.0], labels = labels)

# %%
len(df['age_cat'])
# Out:
# 1306

# %%
df.head(5)
df = df.drop(['True_ID' , 'Age'] , axis=1)

# %%
df.head(5)
# Out:
#    eyesclosed_psd_01dot00hz_lfront  eyesclosed_psd_01dot00hz_mfront  \
# 0                        14.465921                        12.659026
# 1                         4.387368                         6.543729
# 2                         2.349235                         2.438314
# 3                         7.137415                        10.248883
# 4                         8.029552                        13.149798
#
#    eyesclosed_psd_01dot00hz_rfront  eyesclosed_psd_01dot00hz_lpari  \
# 0                        11.387590                       15.525712
# 1                         5.525494                        6.452491
# 2                         3.620102                        3.318841
# 3                         5.708801                        5.134074
# 4                         6.666945                        7.786644
#
#    eyesclosed_psd_01dot00hz_mpari  eyesclosed_psd_01dot00hz_rpari  \
# 0                       17.640830                       15.264459
# ...

# %%
Y = df['age_cat']
X = df.loc[:,df.columns!='age_cat']

# %%
X
# Out:
#       eyesclosed_psd_01dot00hz_lfront  eyesclosed_psd_01dot00hz_mfront  \
# 0                           14.465921                        12.659026
# 1                            4.387368                         6.543729
# 2                            2.349235                         2.438314
# 3                            7.137415                        10.248883
# 4                            8.029552                        13.149798
# ...                               ...                              ...
# 1301                         7.518860                         6.836870
# 1302                         9.218044                        15.719605
# 1303                         6.600199                        11.449236
# 1304                         7.684158                         8.721839
# 1305                         3.344210                         4.167991
#
#       eyesclosed_psd_01dot00hz_rfront  eyesclosed_psd_01dot00hz_lpari  \
# ...

# %%
from sklearn.manifold import TSNE

# %%
n = X.shape[0]
target_dict = {0:'[0,5]' , 1:'[5,10]' , 2:'[10,15]', 3:'[15,20]' , 4:'[20,25]'}
target_ind = target_dict.keys()
target_val = target_dict.values()
index_tot = np.array([])

'''

for i in target_ind :
    n_int = np.argwhere(Y==i)[:,0]
    index_int = np.random.permutation(n_int)[:600]
    index_tot = np.concatenate( (index_tot, index_int) )

index_tot = index_tot.astype(int)

X = X[index_tot]
Y = Y[index_tot]
'''

#get_layer_output = K.function([model.layers[0].input],
#                                  [model.layers[18].output])
#t =get_layer_output([X])[0]

tsne = TSNE(n_components=2, perplexity = 150)
components = tsne.fit_transform(X , Y)

df = pd.DataFrame(data = components,
                          columns = ['component 1' ,
                                    'component 2'])

labels = pd.DataFrame(Y)

finalDf = pd.concat([df, labels] , axis=1)

fig = plt.figure(figsize = (8,8))

ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Component 1', fontsize = 15)
ax.set_ylabel('Component 2', fontsize = 15)
ax.set_title('2 component TSNE for age_category', fontsize = 20)
#targets = ['N': 0, 'S': 1, 'V': 2, 'F': 3, 'Q': 4]
#targets = target_ind #range(4)

colors = ['r', 'g', 'b' , 'y' , 'm'] #k = black #m = magenta
for target, color in zip(target_ind , colors):
    indicesToKeep = labels == target
    indicesToKeep = indicesToKeep.values[:,0]
    ax.scatter(finalDf.loc[indicesToKeep, 'component 1']
               , finalDf.loc[indicesToKeep, 'component 2']
               , c = color
               , s = 50)
ax.legend(target_val)
ax.grid()

plt.savefig('plot_tnse_mit.png')
plt.show()
